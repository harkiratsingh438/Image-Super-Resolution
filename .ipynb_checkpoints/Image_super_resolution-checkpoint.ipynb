# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import cv2
import glob
import tensorflow as tf
from tensorflow.keras import Model, Input, regularizers
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, UpSampling2D, Add, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing import image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
import pickle

# %%
face_images = glob.glob('/content/drive/MyDrive/Colab Notebooks/Image super resolution/lfw/**/*.jpg') #gives path

print(face_images[:2], len(face_images))
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/Image super resolution/lfw/Barry_Switzer/Barry_Switzer_0001.jpg', '/content/drive/MyDrive/Colab Notebooks/Image super resolution/lfw/Barbara_Roberts/Barbara_Roberts_0001.jpg'] 13233

# %%
with open('face_images_path.pickle','wb') as f:
  pickle.dump(face_images,f)

# %%
from tqdm import tqdm

# %%
from multiprocessing import Pool
progress = tqdm(total= len(face_images), position=0)
def read(path):
  img = image.load_img(path, target_size=(80,80,3))
  img = image.img_to_array(img)
  img = img/255.
  progress.update(1)
  return img

p = Pool(10)
img_array = p.map(read, face_images)
# Out:
#  10%|▉         | 1317/13233 [09:45<1:22:08,  2.42it/s]

# %%
with open('img_array.pickle','wb') as f:
  pickle.dump(img_array, f)

# %%
len(img_array)
# Out:
# 13233

# %%
with open('img_array.pickle','rb') as f:
  img_array = pickle.load(f)

# %%
plt.imshow(img_array[100])

# %%
all_images = np.array(img_array)

# %%
#Split test and train data. all_images will be our output images
train_x, val_x = train_test_split(all_images, random_state = 32, test_size=0.2)

# %%
#now we will make input images by lowering resolution without changing the size
def pixalate_image(image, scale_percent = 40):
  width = int(image.shape[1] * scale_percent / 100)
  height = int(image.shape[0] * scale_percent / 100)
  dim = (width, height)

  small_image = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
  
  # scale back to original size
  width = int(small_image.shape[1] * 100 / scale_percent)
  height = int(small_image.shape[0] * 100 / scale_percent)
  dim = (width, height)

  low_res_image = cv2.resize(small_image, dim, interpolation = cv2.INTER_AREA)

  return low_res_image

# %%
train_x_px = []

for i in range(train_x.shape[0]):
  temp = pixalate_image(train_x[i,:,:,:])
  train_x_px.append(temp)

train_x_px = np.array(train_x_px)


# get low resolution images for the validation set
val_x_px = []

for i in range(val_x.shape[0]):
  temp = pixalate_image(val_x[i,:,:,:])
  val_x_px.append(temp)

val_x_px = np.array(val_x_px)

# %%
plt.imshow(train_x[100])

# %%
plt.imshow(train_x_px[100])

# %%
#lets build the model No TPU
#with strategy.scope():
Input_img = Input(shape=(80, 80, 3))  
    
#encoding architecture
x1 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l1(10e-10))(Input_img)
x2 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l1(10e-10))(x1)
x3 = MaxPool2D(padding='same')(x2)

x4 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l1(10e-10))(x3)
x5 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l1(10e-10))(x4)
x6 = MaxPool2D(padding='same')(x5)

encoded = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l1(10e-10))(x6)
#encoded = Conv2D(64, (3, 3), activation='relu', padding='same')(x2)

# decoding architecture
x7 = UpSampling2D()(encoded)
x8 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l1(10e-10))(x7)
x9 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l1(10e-10))(x8)
x10 = Add()([x5, x9])

x11 = UpSampling2D()(x10)
x12 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l1(10e-10))(x11)
x13 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l1(10e-10))(x12)
x14 = Add()([x2, x13])

# x3 = UpSampling2D((2, 2))(x3)
# x2 = Conv2D(128, (3, 3), activation='relu', padding='same')(x3)
# x1 = Conv2D(256, (3, 3), activation='relu', padding='same')(x2)
decoded = Conv2D(3, (3, 3), padding='same',activation='relu', kernel_regularizer=regularizers.l1(10e-10))(x14)

autoencoder = Model(Input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
autoencoder.summary()
early_stopper = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=50, verbose=1, mode='min')
model_checkpoint = ModelCheckpoint('superResolution_checkpoint3.h5',save_best_only=True)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80, 80, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 80, 80, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 80, 80, 64)   36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 40, 40, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 40, 40, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 40, 40, 128)  147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 20, 20, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 20, 20, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 40, 40, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 40, 40, 128)  295040      up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 40, 40, 128)  147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 40, 40, 128)  0           conv2d_3[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 80, 80, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 80, 80, 64)   73792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 80, 80, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 80, 80, 64)   0           conv2d_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 80, 80, 3)    1731        add_1[0][0]
# ==================================================================================================
# Total params: 1,110,403
# Trainable params: 1,110,403
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# #Special dataset pipeline for running model on TPU
# def validation_input_fn(batch_size=1024):
#     # Convert the inputs to a Dataset.
#     dataset = tf.data.Dataset.from_tensor_slices((val_x_px, val_x))
# # Shuffle, repeat, and batch the examples.
#     dataset = dataset.cache()
#     dataset = dataset.shuffle(1000, reshuffle_each_iteration=True)
#     dataset = dataset.repeat()
#     dataset = dataset.batch(batch_size, drop_remainder=True)
# # Return the dataset.
#     return dataset

# %%
history = autoencoder.fit(train_x_px,train_x,
            epochs=100,
            validation_data=(val_x_px, val_x),
            callbacks=[early_stopper, model_checkpoint])
# Out:
# Epoch 1/100
#   2/331 [..............................] - ETA: 14s - loss: 0.1512 - accuracy: 0.2337WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0329s vs `on_train_batch_end` time: 0.0555s). Check your callbacks.
# 331/331 [==============================] - 32s 97ms/step - loss: 0.0052 - accuracy: 0.8625 - val_loss: 0.0027 - val_accuracy: 0.9040
# Epoch 2/100
# 331/331 [==============================] - 32s 96ms/step - loss: 0.0026 - accuracy: 0.9051 - val_loss: 0.0025 - val_accuracy: 0.8989
# Epoch 3/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0025 - accuracy: 0.9084 - val_loss: 0.0024 - val_accuracy: 0.9141
# Epoch 4/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0024 - accuracy: 0.9125 - val_loss: 0.0024 - val_accuracy: 0.8744
# Epoch 5/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0023 - accuracy: 0.9142 - val_loss: 0.0023 - val_accuracy: 0.9036
# Epoch 6/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0023 - accuracy: 0.9162 - val_loss: 0.0022 - val_accuracy: 0.9079
# Epoch 7/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0022 - accuracy: 0.9162 - val_loss: 0.0022 - val_accuracy: 0.9020
# Epoch 8/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0022 - accuracy: 0.9165 - val_loss: 0.0022 - val_accuracy: 0.9200
# Epoch 9/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.
100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0018 - accuracy: 0.9262 - val_loss: 0.0021 - val_accuracy: 0.9257
# Epoch 39/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0018 - accuracy: 0.9278 - val_loss: 0.0021 - val_accuracy: 0.9224
# Epoch 40/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0018 - accuracy: 0.9264 - val_loss: 0.0021 - val_accuracy: 0.9187
# Epoch 41/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0018 - accuracy: 0.9264 - val_loss: 0.0021 - val_accuracy: 0.9080
# Epoch 42/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0018 - accuracy: 0.9267 - val_loss: 0.0021 - val_accuracy: 0.9249
# Epoch 43/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0018 - accuracy: 0.9280 - val_loss: 0.0021 - val_accuracy: 0.9183
# Epoch 44/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0018 - accuracy: 0.9274 - val_loss: 0.0021 - val_accuracy: 0.9227
# Epoch 45/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9267 - val_loss: 0.0021 - val_accuracy: 0.9253
# Epoch 46/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9258 - val_loss: 0.0021 - val_accuracy: 0.9323
# Epoch 47/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9294 - val_loss: 0.0021 - val_accuracy: 0.9359
# Epoch 48/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9283 - val_loss: 0.0021 - val_accuracy: 0.9296
# Epoch 49/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9277 - val_loss: 0.0021 - val_accuracy: 0.9189
# Epoch 50/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9288 - val_loss: 0.0021 - val_accuracy: 0.9139
# Epoch 51/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9281 - val_loss: 0.0021 - val_accuracy: 0.9272
# Epoch 52/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9282 - val_loss: 0.0021 - val_accuracy: 0.9104
# Epoch 53/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9289 - val_loss: 0.0021 - val_accuracy: 0.9374
# Epoch 54/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9282 - val_loss: 0.0021 - val_accuracy: 0.9190
# Epoch 55/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9292 - val_loss: 0.0021 - val_accuracy: 0.9314
# Epoch 56/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9287 - val_loss: 0.0021 - val_accuracy: 0.9264
# Epoch 57/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9295 - val_loss: 0.0021 - val_accuracy: 0.9312
# Epoch 58/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9278 - val_loss: 0.0021 - val_accuracy: 0.9308
# Epoch 59/100
# 331/331 [==============================] - 33s 99ms/step - loss: 0.0017 - accuracy: 0.9292 - val_loss: 0.0021 - val_accuracy: 0.9272
# Epoch 00059: early stopping

# %%
autoencoder = tf.keras.models.load_model('superResolution_checkpoint3.h5')

# %%
predictions = autoencoder.predict(val_x_px)

# %%
n = 4
plt.figure(figsize= (20,10))

for i in range(n):
  ax = plt.subplot(3, n, i+1)
  plt.imshow(val_x_px[i+20])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  ax = plt.subplot(3, n, i+1+n)
  plt.imshow(predictions[i+20])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)


plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
results = autoencoder.evaluate(val_x_px, val_x)
print('loss, accuracy', results)
# Out:
# 83/83 [==============================] - 2s 29ms/step - loss: 0.0021 - accuracy: 0.9240
# loss, accuracy [0.0020675368141382933, 0.9239594340324402]
